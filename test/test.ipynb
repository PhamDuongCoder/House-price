# %%
import pandas as pd
import numpy as np

data = pd.read_csv('Nan_filled_data.csv')
data.columns[data.isnull().any()].tolist()
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'Fence']

# %%
data['Alley'].value_counts(dropna=False)
# Out:
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: count, dtype: int64
